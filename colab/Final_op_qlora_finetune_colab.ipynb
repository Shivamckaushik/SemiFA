# %% [markdown]
# # SemiFA — QLoRA Fine-tuning of LLaVA-1.6
#
# **Author:** Shivam Chand Kaushik
# **Project:** Multi-Modal Vision-Language AI for Semiconductor Inspection & Autonomous FA Report
#
# This notebook fine-tunes LLaVA-1.6 on the SemiFA dataset using QLoRA (4-bit NF4 + LoRA).
#
# ### Requirements
# - **Runtime:** GPU → Change runtime type → **A100** (Colab Pro) or **T4** (free tier, slower)
# - **Storage:** ~15 GB Google Drive space (model weights + adapter)
# - **Time:** A100 ~2–3 hours | T4 ~8–10 hours (790 examples × 3 epochs)
#
# ### What happens
# 1. Mount Drive → upload dataset from your machine once
# 2. Install deps (~5 min)
# 3. Fine-tune LLaVA-1.6 with QLoRA on SemiFA-930
# 4. Adapter saved to Drive — never need to re-upload weights

# %% [markdown]
# ## Step 1 — Mount Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')

# All project files will live here — change if needed
PROJECT_DIR = '/content/drive/MyDrive/SemiFA'

import os
os.makedirs(PROJECT_DIR, exist_ok=True)
print(f'Project dir: {PROJECT_DIR}')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Project dir: /content/drive/MyDrive/SemiFA

# %% [markdown]
# ## Step 2 — Upload dataset from your local machine
#
# **Run this ONCE.** After the first upload, the data lives on your Drive and you can skip this cell.
#
# On your local machine, zip and upload:
# ```
# # From project root (Windows CMD):
# tar -czf semifa_dataset.tar.gz data/processed data/synthetic_dataset/images data/wm811k/images data/mixedwm38/images training/qlora_finetune.py
# ```
# Then upload `semifa_dataset.tar.gz` to `My Drive/SemiFA/` via https://drive.google.com

# %%
import os

ARCHIVE = f'{PROJECT_DIR}/semifa_dataset.tar.gz'
MARKER  = f'{PROJECT_DIR}/.extracted'

if os.path.exists(MARKER):
    print('Dataset already extracted — skipping.')
elif os.path.exists(ARCHIVE):
    print('Extracting archive ...')
    os.system(f'tar -xzf {ARCHIVE} -C {PROJECT_DIR}')
    open(MARKER, 'w').close()
    print('Done.')
else:
    print(f'ERROR: {ARCHIVE} not found.')
    print('Upload semifa_dataset.tar.gz to My Drive/SemiFA/ first.')

# Verify
train_path = f'{PROJECT_DIR}/data/processed/train.jsonl'
if os.path.exists(train_path):
    import json
    n = sum(1 for _ in open(train_path))
    print(f'train.jsonl: {n} records ✓')
else:
    print(f'MISSING: {train_path}')
# Out:
# Extracting archive ...
# Done.
# train.jsonl: 790 records ✓

# %% [markdown]
# ## Step 3 — Verify GPU

# %%
import subprocess
result = subprocess.run(['nvidia-smi'], capture_output=True, text=True)
print(result.stdout)

import torch
print(f'PyTorch  : {torch.__version__}')
print(f'CUDA     : {torch.version.cuda}')
print(f'GPU      : {torch.cuda.get_device_name(0) if torch.cuda.is_available() else "NO GPU"}')
print(f'VRAM     : {torch.cuda.get_device_properties(0).total_memory / 1e9:.1f} GB' if torch.cuda.is_available() else '')

GPU_NAME = torch.cuda.get_device_name(0) if torch.cuda.is_available() else 'cpu'
USE_BF16 = 'A100' in GPU_NAME or 'A6000' in GPU_NAME
BATCH    = 2 if ('A100' in GPU_NAME or 'A6000' in GPU_NAME) else 1
print(f'\nSettings: bf16={USE_BF16}, batch_size={BATCH}')
# Out:
# Sun Apr  5 17:29:56 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA A100-SXM4-40GB          Off |   00000000:00:04.0 Off |                    0 |
# | N/A   31C    P0             46W /  400W |       0MiB /  40960MiB |      0%      Default |
# |                                         |                        |             Disabled |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+
#
# PyTorch  : 2.10.0+cu128
# CUDA     : 12.8
# GPU      : NVIDIA A100-SXM4-40GB
# VRAM     : 42.4 GB
#
# Settings: bf16=True, batch_size=2

# %% [markdown]
# ## Step 4 — Install dependencies

# %%
# Install -- ~5 min on fresh Colab runtime
# !pip install -q     "transformers>=4.41.0"     "peft>=0.10.0"     "bitsandbytes>=0.46.1"     "accelerate>=0.28.0"     Pillow

# Restart runtime so newly installed packages (especially bitsandbytes) are importable
print('Packages installed. Restarting runtime...')
import os, time
time.sleep(2)
os.kill(os.getpid(), 9)
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.7/60.7 MB 45.4 MB/s eta 0:00:00
# Packages installed. Restarting runtime...

# %% [markdown]
# ## Step 5 — Set HuggingFace token
#
# LLaVA-1.6 requires a HF token (model is gated).
# Get yours at: https://huggingface.co/settings/tokens

# %%
import os
from getpass import getpass

hf_token = getpass('Enter HuggingFace token (hf_...): ')
os.environ['HF_TOKEN'] = hf_token
print('Token set ✓')
# Out:
# Enter HuggingFace token (hf_...): ··········
# Token set ✓

# %% [markdown]
# ## Step 6 — Write fine-tuning script
#
# This copies the training script from your uploaded project into the Colab environment.

# %%
import shutil, os

script_src = f'{PROJECT_DIR}/training/qlora_finetune.py'
script_dst = '/content/qlora_finetune.py'

if os.path.exists(script_src):
    shutil.copy(script_src, script_dst)
    print(f'Copied training script → {script_dst} ✓')
else:
    print(f'MISSING: {script_src}')
    print('Make sure the archive was extracted correctly.')
# Out:
# Copied training script → /content/qlora_finetune.py ✓

# %% [markdown]
# ## Step 7 — Run QLoRA fine-tuning
#
# Expected time:
# - **A100 40GB:** ~2–3 hours (790 examples, 3 epochs, batch_size=2)
# - **T4 16GB:** ~8–10 hours (same, batch_size=1)
#
# The adapter will be saved to `PROJECT_DIR/models/llava-semiconductor-qlora/`.

# %%
import subprocess, sys, os

OUTPUT_DIR = f'{PROJECT_DIR}/models/llava-semiconductor-qlora'

cmd = [
    sys.executable, '/content/qlora_finetune.py',
    '--output-dir', OUTPUT_DIR,
    '--image-root', PROJECT_DIR,
    '--epochs', '3',
    '--batch-size', str(BATCH),
    '--grad-accum', '8',
    '--lora-r', '16',
]

# Add --no-bf16 for T4
if not USE_BF16:
    cmd.append('--no-bf16')

# Override JSONL paths to point to Drive
env = os.environ.copy()
env['TRAIN_JSONL'] = f'{PROJECT_DIR}/data/processed/train.jsonl'
env['VAL_JSONL']   = f'{PROJECT_DIR}/data/processed/val.jsonl'

print('Command:', ' '.join(cmd))
print('Output dir:', OUTPUT_DIR)
print('Starting fine-tuning ...\n')

# Run — output streams to cell
process = subprocess.Popen(cmd, stdout=subprocess.PIPE, stderr=subprocess.STDOUT,
                           text=True, env=env)
for line in process.stdout:
    print(line, end='')
process.wait()

if process.returncode == 0:
    print('\n[DONE] Fine-tuning complete ✓')
    print(f'Adapter saved to: {OUTPUT_DIR}')
else:
    print(f'\n[ERROR] Process exited with code {process.returncode}')
# Out:
# Command: /usr/bin/python3 /content/qlora_finetune.py --output-dir /content/drive/MyDrive/SemiFA/models/llava-semiconductor-qlora --image-root /content/drive/MyDrive/SemiFA --epochs 3 --batch-size 2 --grad-accum 8 --lora-r 16
# Output dir: /content/drive/MyDrive/SemiFA/models/llava-semiconductor-qlora
# Starting fine-tuning ...
#
# The image processor of type `LlavaNextImageProcessor` is now loaded as a fast processor by default, even if the model checkpoint was saved with a slow processor. This is a breaking change and may produce slightly different outputs. To continue using the slow processor, instantiate this class with `use_fast=False`.
# [INFO] Base model : llava-hf/llava-v1.6-mistral-7b-hf
# [INFO] Output dir : /content/drive/MyDrive/SemiFA/models/llava-semiconductor-qlora
# [INFO] bf16=True | batch=2 | grad_accum=8
# [INFO] Loading processor ...
# [INFO] Loading model in 4-bit ...
#
# Fetching 4 files:   0%|          | 0/4 [00:00<?, ?it/s]
# Fetching 4 files: 100%|██████████| 4/4 [00:00<00:00, 14254.22it/s]
#
# Loading weights:   0%|          | 0/687 [00:00<?, ?it/s]
# Loading weights:   0%|          | 1/687 [00:00<00:00, 13315.25it/s, Materializing param=model.image_newline]
# Loading weights:   0%|          | 1/687 [00:00<00:00, 6403.52it/s, Materializing param=model.image_newline]
# Loading weights:   0%|          | 2/687 [00:00<00:00, 6065.52it/s, Materializing param=lm_head.weight]
# Loading weights:   0%|          | 2/687 [00:00<00:00, 5047.30it/s, Materializing param=lm_head.weight]
# Loading weights:   0%|          | 3/687 [00:00<00:00, 5372.72it/s, Materializing param=model.language_model.embed_tokens.weight]
# Loading weights:   0%|          | 3/687 [00:00<00:00, 4784.38it/s, Materializing param=model.language_model.embed_tokens.weight]
# Loading weights:   1%|          | 4/687 [00:00<00:03, 197.78it/s, Materializing param=model.language_model.layers.0.input_layernorm.weight]
# Loading weights:   1%|          | 4/687 [00:00<00:03, 196.77it/s, Materializing param=model.language_model.layers.0.input_layernorm.weight]
# Loading weights:   1%|          | 5/687 [00:00<00:02, 243.85it/s, Materializing param=model.language_model.layers.0.mlp.down_proj.weight]
# Loading weights:   1%|          | 5/687 [00:00<00:02, 242.73it/s, Materializing param=model.language_model.layers.0.mlp.down_proj.weight]
# Loading weights:   1%|          | 6/687 [00:00<00:42, 16.01it/s, Materializing param=model.language_model.layers.0.mlp.down_proj.weight]
# Loading weights:   1%|          | 6/687 [00:00<00:42, 16.01it/s, Materializing param=model.language_model.layers.0.mlp.gate_proj.weight]
# Loading weights:   1%|          | 6/687 [00:00<00:42, 16.01it/s, Materializing param=model.language_model.layers.0.mlp.gate_proj.weight]
# Loading weights:   1%|          | 7/687 [00:00<00:42, 16.01it/s, Materializing param=model.language_model.layers.0.mlp.up_proj.weight]
# Loading weights:   1%|          | 7/687 [00:00<00:42, 16.01it/s, Materializing param=model.language_model.layers.0.mlp.up_proj.weight]
# Loading weights:   1%|          | 8/687 [00:01<01:42,  6.65it/s, Materializing param=model.language_model.layers.0.mlp.up_proj.weight]
# Loading weights:   1%|          | 8/687 [00:01<01:42,  6.65it/s, Materializing param=model.language_model.layers.0.post_attention_layernorm.weight]
# Loading weights:   1%|          | 8/687 [00:01<01:42,  6.65it/s, Materializing param=model.language_model.layers.0.post_attention_layernorm.weight]
# Loading weights:   1%|▏         | 9/687 [00:01<01:41,  6.65it/s, Materializing param=model.language_model.layers.0.self_attn.k_proj.weight]
# Loading weights:   1%|▏         | 9/687 [00:01<01:41,  6.65it/s, Materializing param=model.language_model.layers.0.self_attn.k_proj.weight]
# Loading weights:   1%|▏         | 10/687 [00:01<02:08,  5.28it/s, Materializing param=model.language_model.layers.0.self_attn.k_proj.weight]
# Loading weights:   1%|▏         | 10/687 [00:01<02:08,  5.28it/s, Materializing param=model.language_model.layers.0.self_attn.o_proj.weight]
# Loading weights:   3%|▎         | 20/687 [00:03<03:12,  3.46it/s, Materializing param=model.language_model.layers.1.self_attn.q_proj.weight]
# Loading weights:   3%|▎         | 20/687 [00:03<03:12,  3.46it/s, Materializing param=model.language_model.layers.1.self_attn.q_proj.weight]
# Loading weights:   3%|▎         | 21/687 [00:03<03:12,  3.46it/s, Materializing param=model.language_model.layers.1.self_attn.v_proj.weight]
# Loading weights:   3%|▎         | 21/687 [00:03<03:12,  3.46it/s, Materializing param=model.language_model.layers.1.self_attn.v_proj.weight]
# Loading weights:   3%|▎         | 22/687 [00:03<03:12,  3.46it/s, Materializing param=model.language_model.layers.2.input_layernorm.weight]
# Loading weights:   3%|▎         | 22/687 [00:03<03:12,  3.46it/s, Materializing param=model.language_model.layers.2.input_layernorm.weight]
# Loading weights:   3%|▎         | 23/687 [00:03<03:11,  3.46it/s, Materializing param=model.language_model.layers.2.mlp.down_proj.weight]
# Loading weights:   3%|▎         | 23/687 [00:03<03:11,  3.46it/s, Materializing param=model.language_model.layers.2.mlp.down_proj.weight]
# Loading weights:   3%|▎         | 24/687 [00:03<03:11,  3.46it/s, Materializing param=model.language_model.layers.2.mlp.gate_proj.weight]
# Loading weights:   3%|▎         | 24/687 [00:03<03:11,  3.46it/s, Materializing param=model.language_model.layers.2.mlp.gate_proj.weight]
# Loading weights:   4%|▎         | 25/687 [00:03<03:11,  3.46it/s, Materializing param=model.language_model.layers.2.mlp.up_proj.weight]
# Loading weights:   4%|▎         | 25/687 [00:03<03:11,  3.46it/s, Materializing param=model.language_model.layers.2.mlp.up_proj.weight]
# Loading weights:   4%|▍         | 26/687 [00:03<03:11,  3.46it/s, Materializing param=model.language_model.layers.2.post_attention_layernorm.weight]
# Loading weights:   4%|▍         | 26/687 [00:03<03:11,  3.46it/s, Materializing param=model.language_model.layers.2.post_attention_layernorm.weight]
# Loading weights:   4%|▍         | 27/687 [00:03<03:10,  3.46it/s, Materializing param=model.language_model.layers.2.self_attn.k_proj.weight]
# Loading weights:   4%|▍         | 27/687 [00:03<03:10,  3.46it/s, Materializing param=model.language_model.layers.2.self_attn.k_proj.weight]
# Loading weights:   4%|▍         | 28/687 [00:03<03:10,  3.46it/s, Materializing param=model.language_model.layers.2.self_attn.o_proj.weight]
# Loading weights:   4%|▍         | 28/687 [00:03<03:10,  3.46it/s, Materializing param=model.language_model.layers.2.self_attn.o_proj.weight]
# Loading weights:   4%|▍         | 29/687 [00:03<00:42, 15.61it/s, Materializing param=model.language_model.layers.2.self_attn.o_proj.weight]
# Loading weights:   4%|▍         | 29/687 [00:03<00:42, 15.61it/s, Materializing param=model.language_model.layers.2.self_attn.q_proj.weight]
# Loading weights:   4%|▍         | 29/687 [00:03<00:42, 15.61it/s, Materializing param=model.language_model.layers.2.self_attn.q_proj.weight]
# Loading weights:   4%|▍         | 30/687 [00:03<00:42, 15.61it/s, Materializing param=model.language_model.layers.2.self_attn.v_proj.weight]
# Loading weights:   4%|▍         | 30/687 [00:03<00:42, 15.61it/s, Materializing param=model.language_model.layers.2.self_attn.v_proj.weight]
# Loading weights:   5%|▍         | 31/687 [00:03<00:42, 15.61it/s, Materializing param=model.language_model.layers.3.input_layernorm.weight]
# Loading weights:   5%|▍         | 31/687 [00:03<00:42, 15.61it/s, Materializing param=model.language_model.layers.3.input_layernorm.weight]
# Loading weights:   5%|▍         | 32/687 [00:03<00:41, 15.61it/s, Materializing param=model.language_model.layers.3.mlp.down_proj.weight]
# Loading weights:   5%|▍         | 32/687 [00:03<00:41, 15.61it/s, Materializing param=model.language_model.layers.3.mlp.down_proj.weight]
# Loading weights:   5%|▍         | 33/687 [00:03<00:41, 15.61it/s, Materializing param=model.language_model.layers.3.mlp.gate_proj.weight]
# Loading weights:   5%|▍         | 33/687 [00:03<00:41, 15.61it/s, Materializing param=model.language_model.layers.3.mlp.gate_proj.weight]
# Loading weights:   5%|▍         | 34/687 [00:03<00:41, 15.61it/s, Materializing param=model.language_model.layers.3.mlp.up_proj.weight]
# Loading weights:   5%|▍         | 34/687 [00:03<00:41, 15.61it/s, Materializing param=model.language_model.layers.3.mlp.up_proj.weight]
# Loading weights:   5%|▌         | 35/687 [00:03<00:41, 15.61it/s, Materializing param=model.language_model.layers.3.post_attention_layernorm.weight]
# Loading weights:   5%|▌         | 35/687 [00:03<00:41, 15.61it/s, Materializing param=model.language_model.layers.3.post_attention_layernorm.weight]
# Loading weights:   5%|▌         | 36/687 [00:03<00:41, 15.61it/s, Materializing param=model.language_model.layers.3.self_attn.k_proj.weight]
# Loading weights:   5%|▌         | 36/687 [00:03<00:41, 15.61it/s, Materializing param=model.language_model.layers.3.self_attn.k_proj.weight]
# Loading weights:   5%|▌         | 37/687 [00:03<00:41, 15.61it/s, Materializing param=model.language_model.layers.3.self_attn.o_proj.weight]
# Loading weights:   5%|▌         | 37/687 [00:03<00:41, 15.61it/s, Materializing param=model.language_model.layers.3.self_attn.o_proj.weight]
# Loading weights:   6%|▌         | 38/687 [00:03<00:41, 15.61it/s, Materializing param=model.language_model.layers.3.self_attn.q_proj.weight]
# Loading weights:   6%|▌         | 38/687 [00:03<00:41, 15.61it/s, Materializing param=model.language_model.layers.3.self_attn.q_proj.weight]
# Loading weights:   6%|▌         | 39/687 [00:03<00:41, 15.61it/s, Materializing param=model.language_model.layers.3.self_attn.v_proj.weight]
# Loading weights:   6%|▌         | 39/687 [00:03<00:41, 15.61it/s, Materializing param=model.language_model.layers.3.self_attn.v_proj.weight]
# Loading weights:   6%|▌         | 40/687 [00:03<00:41, 15.61it/s, Materializing param=model.language_model.layers.4.input_layernorm.weight]
# Loading weights:   6%|▌         | 40/687 [00:03<00:41, 15.61it/s, Materializing param=model.language_model.layers.4.input_layernorm.weight]
# Loading weights:   6%|▌         | 41/687 [00:03<00:41, 15.61it/s, Materializing param=model.language_model.layers.4.mlp.down_proj.weight]
# Loading weights:   6%|▌         | 41/687 [00:03<00:41, 15.61it/s, Materializing param=model.language_model.layers.4.mlp.down_proj.weight]
# Loading weights:   6%|▌         | 42/687 [00:03<00:41, 15.61it/s, Materializing param=model.language_model.layers.4.mlp.gate_proj.weight]
# Loading weights:   6%|▌         | 42/687 [00:03<00:41, 15.61it/s, Materializing param=model.language_model.layers.4.mlp.gate_proj.weight]
# Loading weights:   6%|▋         | 43/687 [00:03<00:41, 15.61it/s, Materializing param=model.language_model.layers.4.mlp.up_proj.weight]
# Loading weights:   6%|▋         | 43/687 [00:03<00:41, 15.61it/s, Materializing param=model.language_model.layers.4.mlp.up_proj.weight]
# Loading weights:   6%|▋         | 44/687 [00:03<00:20, 30.72it/s, Materializing param=model.language_model.layers.4.mlp.up_proj.weight]
# Loading weights:   6%|▋         | 44/687 [00:03<00:20, 30.72it/s, Materializing param=model.language_model.layers.4.post_attention_layernorm.weight]
# Loading weights:   6%|▋         | 44/687 [00:03<00:20, 30.72it/s, Materializing param=model.language_model.layers.4.post_attention_layernorm.weight]
# Loading weights:   7%|▋         | 45/687 [00:03<00:20, 30.72it/s, Materializing param=model.language_model.layers.4.self_attn.k_proj.weight]
# Loading weights:   7%|▋         | 45/687 [00:03<00:20, 30.72it/s, Materializing param=model.language_model.layers.4.self_attn.k_proj.weight]
# Loading weights:   7%|▋         | 46/687 [00:03<00:20, 30.72it/s, Materializing param=model.language_model.layers.4.self_attn.o_proj.weight]
# Loading weights:   7%|▋         | 46/687 [00:03<00:20, 30.72it/s, Materializing param=model.language_model.layers.4.self_attn.o_proj.weight]
# Loading weights:   7%|▋         | 47/687 [00:03<00:20, 30.72it/s, Materializing param=model.language_model.layers.4.self_attn.q_proj.weight]
# Loading weights:   7%|▋         | 47/687 [00:03<00:20, 30.72it/s, Materializing param=model.language_model.layers.4.self_attn.q_proj.weight]
# Loading weights:   7%|▋         | 48/687 [00:03<00:20, 30.72it/s, Materializing param=model.language_model.layers.4.self_attn.v_proj.weight]
# Loading weights:   7%|▋         | 48/687 [00:03<00:20, 30.72it/s, Materializing param=model.language_model.layers.4.self_attn.v_proj.weight]
# Loading weights:   7%|▋         | 49/687 [00:03<00:20, 30.72it/s, Materializing param=model.language_model.layers.5.input_layernorm.weight]
# Loading weights:   7%|▋         | 49/687 [00:03<00:20, 30.72it/s, Materializing param=model.language_model.layers.5.input_layernorm.weight]
# Loading weights:   7%|▋         | 50/687 [00:03<00:20, 30.72it/s, Materializing param=model.language_model.layers.5.mlp.down_proj.weight]
# Loading weights:   7%|▋         | 50/687 [00:03<00:20, 30.72it/s, Materializing param=model.language_model.layers.5.mlp.down_proj.weight]
# Loading weights:   7%|▋         | 51/687 [00:03<00:20, 30.72it/s, Materializing param=model.language_model.layers.5.mlp.gate_proj.weight]
# Loading weights:   7%|▋         | 51/687 [00:03<00:20, 30.72it/s, Materializing param=model.language_model.layers.5.mlp.gate_proj.weight]
# Loading weights:   8%|▊         | 52/687 [00:03<00:20, 30.72it/s, Materializing param=model.language_model.layers.5.mlp.up_proj.weight]
# Loading weights:   8%|▊         | 52/687 [00:03<00:20, 30.72it/s, Materializing param=model.language_model.layers.5.mlp.up_proj.weight]
# Loading weights:   8%|▊         | 53/687 [00:03<00:20, 30.72it/s, Materializing param=model.language_model.layers.5.post_attention_layernorm.weight]
# Loading weights:   8%|▊         | 53/687 [00:03<00:20, 30.72it/s, Materializing param=model.language_model.layers.5.post_attention_layernorm.weight]
# Loading weights:   8%|▊         | 54/687 [00:03<00:20, 30.72it/s, Materializing param=model.language_model.layers.5.self_attn.k_proj.weight]
# Loading weights:   8%|▊         | 54/687 [00:03<00:20, 30.72it/s, Materializing param=model.language_model.layers.5.self_attn.k_proj.weight]
# Loading weights:   8%|▊         | 55/687 [00:03<00:20, 30.72it/s, Materializing param=model.language_model.layers.5.self_attn.o_proj.weight]
# Loading weights:   8%|▊         | 55/687 [00:03<00:20, 30.72it/s, Materializing param=model.language_model.layers.5.self_attn.o_proj.weight]
# Loading weights:   8%|▊         | 56/687 [00:03<00:20, 30.72it/s, Materializing param=model.language_model.layers.5.self_attn.q_proj.weight]
# Loading weights:   8%|▊         | 56/687 [00:03<00:20, 30.72it/s, Materializing param=model.language_model.layers.5.self_attn.q_proj.weight]
# Loading weights:   8%|▊         | 57/687 [00:03<00:20, 30.72it/s, Materializing param=model.language_model.layers.5.self_attn.v_proj.weight]
# Loading weights:   8%|▊         | 57/687 [00:03<00:20, 30.72it/s, Materializing param=model.language_model.layers.5.self_attn.v_proj.weight]
# Loading weights:   8%|▊         | 58/687 [00:03<00:20, 30.72it/s, Materializing param=model.language_model.layers.6.input_layernorm.weight]
# Loading weights:   8%|▊         | 58/687 [00:03<00:20, 30.72it/s, Materializing param=model.language_model.layers.6.input_layernorm.weight]
# Loading weights:   9%|▊         | 59/687 [00:03<00:20, 30.72it/s, Materializing param=model.language_model.layers.6.mlp.down_proj.weight]
# Loading weights:   9%|▊         | 59/687 [00:03<00:20, 30.72it/s, Materializing param=model.language_model.layers.6.mlp.down_proj.weight]
# Loading weights:   9%|▊         | 60/687 [00:03<00:20, 30.72it/s, Materializing param=model.language_model.layers.6.mlp.gate_proj.weight]
# Loading weights:   9%|▊         | 60/687 [00:03<00:20, 30.72it/s, Materializing param=model.language_model.layers.6.mlp.gate_proj.weight]
# Loading weights:   9%|▉         | 61/687 [00:03<00:20, 30.72it/s, Materializing param=model.language_model.layers.6.mlp.up_proj.weight]
# Loading weights:   9%|▉         | 61/687 [00:03<00:20, 30.72it/s, Materializing param=model.language_model.layers.6.mlp.up_proj.weight]
# Loading weights:   9%|▉         | 62/687 [00:03<00:20, 30.72it/s, Materializing param=model.language_model.layers.6.post_attention_layernorm.weight]
# Loading weights:   9%|▉         | 62/687 [00:03<00:20, 30.72it/s, Materializing param=model.language_model.layers.6.post_attention_layernorm.weight]
# Loading weights:   9%|▉         | 63/687 [00:03<00:20, 30.72it/s, Materializing param=model.language_model.layers.6.self_attn.k_proj.weight]
# Loading weights:   9%|▉         | 63/687 [00:03<00:20, 30.72it/s, Materializing param=model.language_model.layers.6.self_attn.k_proj.weight]
# Loading weights:   9%|▉         | 64/687 [00:03<00:20, 30.72it/s, Materializing param=model.language_model.layers.6.self_attn.o_proj.weight]
# Loading weights:   9%|▉         | 64/687 [00:03<00:20, 30.72it/s, Materializing param=model.language_model.layers.6.self_attn.o_proj.weight]
# Loading weights:   9%|▉         | 65/687 [00:03<00:20, 30.72it/s, Materializing param=model.language_model.layers.6.self_attn.q_proj.weight]
# Loading weights:   9%|▉         | 65/687 [00:03<00:20, 30.72it/s, Materializing param=model.language_model.layers.6.self_attn.q_proj.weight]
# Loading weights:  10%|▉         | 66/687 [00:03<00:20, 30.72it/s, Materializing param=model.language_model.layers.6.self_attn.v_proj.weight]
# Loading weights:  10%|▉         | 66/687 [00:03<00:20, 30.72it/s, Materializing param=model.language_model.layers.6.self_attn.v_proj.weight]
# Loading weights:  10%|▉         | 67/687 [00:03<00:20, 30.72it/s, Materializing param=model.language_model.layers.7.input_layernorm.weight]
# Loading weights:  10%|▉         | 67/687 [00:03<00:20, 30.72it/s, Materializing param=model.language_model.layers.7.input_layernorm.weight]
# Loading weights:  10%|▉         | 68/687 [00:03<00:20, 30.72it/s, Materializing param=model.language_model.layers.7.mlp.down_proj.weight]
# Loading weights:  10%|▉         | 68/687 [00:03<00:20, 30.72it/s, Materializing param=model.language_model.layers.7.mlp.down_proj.weight]
# Loading weights:  10%|█         | 69/687 [00:03<00:20, 30.72it/s, Materializing param=model.language_model.layers.7.mlp.gate_proj.weight]
# Loading weights:  10%|█         | 69/687 [00:03<00:20, 30.72it/s, Materializing param=model.language_model.layers.7.mlp.gate_proj.weight]
# Loading weights:  10%|█         | 70/687 [00:03<00:20, 30.72it/s, Materializing param=model.language_model.layers.7.mlp.up_proj.weight]
# Loading weights:  10%|█         | 70/687 [00:03<00:20, 30.72it/s, Materializing param=model.language_model.layers.7.mlp.up_proj.weight]
# Loading weights:  10%|█         | 71/687 [00:03<00:20, 30.72it/s, Materializing param=model.language_model.layers.7.post_attention_layernorm.weight]
# Loading weights:  10%|█         | 71/687 [00:03<00:20, 30.72it/s, Materializing param=model.language_model.layers.7.post_attention_layernorm.weight]
# Loading weights:  10%|█         | 72/687 [00:03<00:20, 30.72it/s, Materializing param=model.language_model.layers.7.self_attn.k_proj.weight]
# Loading weights:  10%|█         | 72/687 [00:03<00:20, 30.72it/s, Materializing param=model.language_model.layers.7.self_attn.k_proj.weight]
# Loading weights:  11%|█         | 73/687 [00:03<00:19, 30.72it/s, Materializing param=model.language_model.layers.7.self_attn.o_proj.weight]
# Loading weights:  11%|█         | 73/687 [00:03<00:19, 30.72it/s, Materializing param=model.language_model.layers.7.self_attn.o_proj.weight]
# Loading weights:  11%|█         | 74/687 [00:03<00:19, 30.72it/s, Materializing param=model.language_model.layers.7.self_attn.q_proj.weight]
# Loading weights:  11%|█         | 74/687 [00:03<00:19, 30.72it/s, Materializing param=model.language_model.layers.7.self_attn.q_proj.weight]
# Loading weights:  11%|█         | 75/687 [00:03<00:19, 30.72it/s, Materializing param=model.language_model.layers.7.self_attn.v_proj.weight]
# Loading weights:  11%|█         | 75/687 [00:03<00:19, 30.72it/s, Materializing param=model.language_model.layers.7.self_attn.v_proj.weight]
# Loading weights:  11%|█         | 76/687 [00:03<00:19, 30.72it/s, Materializing param=model.language_model.layers.8.input_layernorm.weight]
# Loading weights:  11%|█         | 76/687 [00:03<00:19, 30.72it/s, Materializing param=model.language_model.layers.8.input_layernorm.weight]
# Loading weights:  11%|█         | 77/687 [00:03<00:19, 30.72it/s, Materializing param=model.language_model.layers.8.mlp.down_proj.weight]
# Loading weights:  11%|█         | 77/687 [00:03<00:19, 30.72it/s, Materializing param=model.language_model.layers.8.mlp.down_proj.weight]
# Loading weights:  11%|█▏        | 78/687 [00:03<00:19, 30.72it/s, Materializing param=model.language_model.layers.8.mlp.gate_proj.weight]
# Loading weights:  11%|█▏        | 78/687 [00:03<00:19, 30.72it/s, Materializing param=model.language_model.layers.8.mlp.gate_proj.weight]
# Loading weights:  11%|█▏        | 79/687 [00:03<00:19, 30.72it/s, Materializing param=model.language_model.layers.8.mlp.up_proj.weight]
# Loading weights:  11%|█▏        | 79/687 [00:03<00:19, 30.72it/s, Materializing param=model.language_model.layers.8.mlp.up_proj.weight]
# Loading weights:  12%|█▏        | 80/687 [00:03<00:19, 30.72it/s, Materializing param=model.language_model.layers.8.post_attention_layernorm.weight]
# Loading weights:  12%|█▏        | 80/687 [00:03<00:19, 30.72it/s, Materializing param=model.language_model.layers.8.post_attention_layernorm.weight]
# Loading weights:  12%|█▏        | 81/687 [00:03<00:19, 30.72it/s, Materializing param=model.language_model.layers.8.self_attn.k_proj.weight]
# Loading weights:  12%|█▏        | 81/687 [00:03<00:19, 30.72it/s, Materializing param=model.language_model.layers.8.self_attn.k_proj.weight]
# Loading weights:  12%|█▏        | 82/687 [00:03<00:19, 30.72it/s, Materializing param=model.language_model.layers.8.self_attn.o_proj.weight]
# Loading weights:  12%|█▏        | 82/687 [00:03<00:19, 30.72it/s, Materializing param=model.language_model.layers.8.self_attn.o_proj.weight]
# Loading weights:  12%|█▏        | 83/687 [00:03<00:19, 30.72it/s, Materializing param=model.language_model.layers.8.self_attn.q_proj.weight]
# Loading weights:  12%|█▏        | 83/687 [00:03<00:19, 30.72it/s, Materializing param=model.language_model.layers.8.self_attn.q_proj.weight]
# Loading weights:  12%|█▏        | 84/687 [00:03<00:19, 30.72it/s, Materializing param=model.language_model.layers.8.self_attn.v_proj.weight]
# Loading weights:  12%|█▏        | 84/687 [00:03<00:19, 30.72it/s, Materializing param=model.language_model.layers.8.self_attn.v_proj.weight]
# Loading weights:  12%|█▏        | 85/687 [00:03<00:19, 30.72it/s, Materializing param=model.language_model.layers.9.input_layernorm.weight]
# Loading weights:  12%|█▏        | 85/687 [00:03<00:19, 30.72it/s, Materializing param=model.language_model.layers.9.input_layernorm.weight]
# Loading weights:  13%|█▎        | 86/687 [00:03<00:19, 30.72it/s, Materializing param=model.language_model.layers.9.mlp.down_proj.weight]
# Loading weights:  13%|█▎        | 86/687 [00:03<00:19, 30.72it/s, Materializing param=model.language_model.layers.9.mlp.down_proj.weight]
# Loading weights:  13%|█▎        | 87/687 [00:03<00:19, 30.72it/s, Materializing param=model.language_model.layers.9.mlp.gate_proj.weight]
# Loading weights:  13%|█▎        | 87/687 [00:03<00:19, 30.72it/s, Materializing param=model.language_model.layers.9.mlp.gate_proj.weight]
# Loading weights:  13%|█▎        | 88/687 [00:03<00:19, 30.72it/s, Materializing param=model.language_model.layers.9.mlp.up_proj.weight]
# Loading weights:  13%|█▎        | 88/687 [00:03<00:19, 30.72it/s, Materializing param=model.language_model.layers.9.mlp.up_proj.weight]
# Loading weights:  13%|█▎        | 89/687 [00:03<00:19, 30.72it/s, Materializing param=model.language_model.layers.9.post_attention_layernorm.weight]
# Loading weights:  13%|█▎        | 89/687 [00:03<00:19, 30.72it/s, Materializing param=model.language_model.layers.9.post_attention_layernorm.weight]
# Loading weights:  13%|█▎        | 90/687 [00:03<00:19, 30.72it/s, Materializing param=model.language_model.layers.9.self_attn.k_proj.weight]
# Loading weights:  13%|█▎        | 90/687 [00:03<00:19, 30.72it/s, Materializing param=model.language_model.layers.9.self_attn.k_proj.weight]
# Loading weights:  13%|█▎        | 91/687 [00:03<00:19, 30.72it/s, Materializing param=model.language_model.layers.9.self_attn.o_proj.weight]
# Loading weights:  13%|█▎        | 91/687 [00:03<00:19, 30.72it/s, Materializing param=model.language_model.layers.9.self_attn.o_proj.weight]
# Loading weights:  13%|█▎        | 92/687 [00:03<00:19, 30.72it/s, Materializing param=model.language_model.layers.9.self_attn.q_proj.weight]
# Loading weights:  13%|█▎        | 92/687 [00:03<00:19, 30.72it/s, Materializing param=model.language_model.layers.9.self_attn.q_proj.weight]
# Loading weights:  14%|█▎        | 93/687 [00:03<00:19, 30.72it/s, Materializing param=model.language_model.layers.9.self_attn.v_proj.weight]
# Loading weights:  14%|█▎        | 93/687 [00:03<00:19, 30.72it/s, Materializing param=model.language_model.layers.9.self_attn.v_proj.weight]
# Loading weights:  14%|█▎        | 94/687 [00:03<00:19, 30.72it/s, Materializing param=model.language_model.layers.10.input_layernorm.weight]
# Loading weights:  14%|█▎        | 94/687 [00:03<00:19, 30.72it/s, Materializing param=model.language_model.layers.10.input_layernorm.weight]
# Loading weights:  14%|█▍        | 95/687 [00:03<00:19, 30.72it/s, Materializing param=model.language_model.layers.10.mlp.down_proj.weight]
# Loading weights:  14%|█▍        | 95/687 [00:03<00:19, 30.72it/s, Materializing param=model.language_model.layers.10.mlp.down_proj.weight]
# Loading weights:  14%|█▍        | 96/687 [00:03<00:19, 30.72it/s, Materializing param=model.language_model.layers.10.mlp.gate_proj.weight]
# Loading weights:  14%|█▍        | 96/687 [00:03<00:19, 30.72it/s, Materializing param=model.language_model.layers.10.mlp.gate_proj.weight]
# Loading weights:  14%|█▍        | 97/687 [00:03<00:19, 30.72it/s, Materializing param=model.language_model.layers.10.mlp.up_proj.weight]
# Loading weights:  14%|█▍        | 97/687 [00:03<00:19, 30.72it/s, Materializing param=model.language_model.layers.10.mlp.up_proj.weight]
# Loading weights:  14%|█▍        | 98/687 [00:03<00:19, 30.72it/s, Materializing param=model.language_model.layers.10.post_attention_layernorm.weight]
# Loading weights:  14%|█▍        | 98/687 [00:03<00:19, 30.72it/s, Materializing param=model.language_model.layers.10.post_attention_layernorm.weight]
# Loading weights:  14%|█▍        | 99/687 [00:03<00:19, 30.72it/s, Materializing param=model.language_model.layers.10.self_attn.k_proj.weight]
# Loading weights:  14%|█▍        | 99/687 [00:03<00:19, 30.72it/s, Materializing param=model.language_model.layers.10.self_attn.k_proj.weight]
# Loading weights:  15%|█▍        | 100/687 [00:03<00:19, 30.72it/s, Materializing param=model.language_model.layers.10.self_attn.o_proj.weight]
# Loading weights:  15%|█▍        | 100/687 [00:03<00:19, 30.72it/s, Materializing param=model.language_model.layers.10.self_attn.o_proj.weight]
# Loading weights:  15%|█▍        | 101/687 [00:03<00:19, 30.72it/s, Materializing param=model.language_model.layers.10.self_attn.q_proj.weight]
# Loading weights:  15%|█▍        | 101/687 [00:03<00:19, 30.72it/s, Materializing param=model.language_model.layers.10.self_attn.q_proj.weight]
# Loading weights:  15%|█▍        | 102/687 [00:03<00:19, 30.72it/s, Materializing param=model.language_model.layers.10.self_attn.v_proj.weight]
# Loading weights:  15%|█▍        | 102/687 [00:03<00:19, 30.72it/s, Materializing param=model.language_model.layers.10.self_attn.v_proj.weight]
# Loading weights:  15%|█▍        | 103/687 [00:03<00:19, 30.72it/s, Materializing param=model.language_model.layers.11.input_layernorm.weight]
# Loading weights:  15%|█▍        | 103/687 [00:03<00:19, 30.72it/s, Materializing param=model.language_model.layers.11.input_layernorm.weight]
# Loading weights:  15%|█▌        | 104/687 [00:03<00:18, 30.72it/s, Materializing param=model.language_model.layers.11.mlp.down_proj.weight]
# Loading weights:  15%|█▌        | 104/687 [00:03<00:18, 30.72it/s, Materializing param=model.language_model.layers.11.mlp.down_proj.weight]
# Loading weights:  15%|█▌        | 105/687 [00:03<00:18, 30.72it/s, Materializing param=model.language_model.layers.11.mlp.gate_proj.weight]
# Loading weights:  15%|█▌        | 105/687 [00:03<00:18, 30.72it/s, Materializing param=model.language_model.layers.11.mlp.gate_proj.weight]
# Loading weights:  15%|█▌        | 106/687 [00:03<00:18, 30.72it/s, Materializing param=model.language_model.layers.11.mlp.up_proj.weight]
# Loading weights:  15%|█▌        | 106/687 [00:03<00:18, 30.72it/s, Materializing param=model.language_model.layers.11.mlp.up_proj.weight]
# Loading weights:  16%|█▌        | 107/687 [00:03<00:18, 30.72it/s, Materializing param=model.language_model.layers.11.post_attention_layernorm.weight]
# Loading weights:  16%|█▌        | 107/687 [00:03<00:18, 30.72it/s, Materializing param=model.language_model.layers.11.post_attention_layernorm.weight]
# Loading weights:  16%|█▌        | 108/687 [00:03<00:18, 30.72it/s, Materializing param=model.language_model.layers.11.self_attn.k_proj.weight]
# Loading weights:  16%|█▌        | 108/687 [00:03<00:18, 30.72it/s, Materializing param=model.language_model.layers.11.self_attn.k_proj.weight]
# Loading weights:  16%|█▌        | 109/687 [00:03<00:18, 30.72it/s, Materializing param=model.language_model.layers.11.self_attn.o_proj.weight]
# Loading weights:  16%|█▌        | 109/687 [00:03<00:18, 30.72it/s, Materializing param=model.language_model.layers.11.self_attn.o_proj.weight]
# Loading weights:  16%|█▌        | 110/687 [00:03<00:18, 30.72it/s, Materializing param=model.language_model.layers.11.self_attn.q_proj.weight]
# Loading weights:  16%|█▌        | 110/687 [00:03<00:18, 30.72it/s, Materializing param=model.language_model.layers.11.self_attn.q_proj.weight]
# Loading weights:  16%|█▌        | 111/687 [00:03<00:18, 30.72it/s, Materializing param=model.language_model.layers.11.self_attn.v_proj.weight]
# Loading weights:  16%|█▌        | 111/687 [00:03<00:18, 30.72it/s, Materializing param=model.language_model.layers.11.self_attn.v_proj.weight]
# Loading weights:  16%|█▋        | 112/687 [00:03<00:18, 30.72it/s, Materializing param=model.language_model.layers.12.input_layernorm.weight]
# Loading weights:  16%|█▋        | 112/687 [00:03<00:18, 30.72it/s, Materializing param=model.language_model.layers.12.input_layernorm.weight]
# Loading weights:  16%|█▋        | 113/687 [00:03<00:18, 30.72it/s, Materializing param=model.language_model.layers.12.mlp.down_proj.weight]
# Loading weights:  16%|█▋        | 113/687 [00:03<00:18, 30.72it/s, Materializing param=model.language_model.layers.12.mlp.down_proj.weight]
# Loading weights:  17%|█▋        | 114/687 [00:03<00:18, 30.72it/s, Materializing param=model.language_model.layers.12.mlp.gate_proj.weight]
# Loading weights:  17%|█▋        | 114/687 [00:03<00:18, 30.72it/s, Materializing param=model.language_model.layers.12.mlp.gate_proj.weight]
# Loading weights:  17%|█▋        | 115/687 [00:03<00:18, 30.72it/s, Materializing param=model.language_model.layers.12.mlp.up_proj.weight]
# Loading weights:  17%|█▋        | 115/687 [00:03<00:18, 30.72it/s, Materializing param=model.language_model.layers.12.mlp.up_proj.weight]
# Loading weights:  17%|█▋        | 116/687 [00:03<00:18, 30.72it/s, Materializing param=model.language_model.layers.12.post_attention_layernorm.weight]
# Loading weights:  17%|█▋        | 116/687 [00:03<00:18, 30.72it/s, Materializing param=model.language_model.layers.12.post_attention_layernorm.weight]
# Loading weights:  17%|█▋        | 117/687 [00:03<00:18, 30.72it/s, Materializing param=model.language_model.layers.12.self_attn.k_proj.weight]
# Loading weights:  17%|█▋        | 117/687 [00:03<00:18, 30.72it/s, Materializing param=model.language_model.layers.12.self_attn.k_proj.weight]
# Loading weights:  17%|█▋        | 118/687 [00:03<00:18, 30.72it/s, Materializing param=model.language_model.layers.12.self_attn.o_proj.weight]
# Loading weights:  17%|█▋        | 118/687 [00:03<00:18, 30.72it/s, Materializing param=model.language_model.layers.12.self_attn.o_proj.weight]
# Loading weights:  17%|█▋        | 119/687 [00:03<00:18, 30.72it/s, Materializing param=model.language_model.layers.12.self_attn.q_proj.weight]
# Loading weights:  17%|█▋        | 119/687 [00:03<00:18, 30.72it/s, Materializing param=model.language_model.layers.12.self_attn.q_proj.weight]
# Loading weights:  17%|█▋        | 120/687 [00:03<00:18, 30.72it/s, Materializing param=model.language_model.layers.12.self_attn.v_proj.weight]
# Loading weights:  17%|█▋        | 120/687 [00:03<00:18, 30.72it/s, Materializing param=model.language_model.layers.12.self_attn.v_proj.weight]
# Loading weights:  18%|█▊        | 121/687 [00:03<00:18, 30.72it/s, Materializing param=model.language_model.layers.13.input_layernorm.weight]
# Loading weights:  18%|█▊        | 121/687 [00:03<00:18, 30.72it/s, Materializing param=model.language_model.layers.13.input_layernorm.weight]
# Loading weights:  18%|█▊        | 122/687 [00:03<00:18, 30.72it/s, Materializing param=model.language_model.layers.13.mlp.down_proj.weight]
# Loading weights:  18%|█▊        | 122/687 [00:03<00:18, 30.72it/s, Materializing param=model.language_model.layers.13.mlp.down_proj.weight]
# Loading weights:  18%|█▊        | 123/687 [00:03<00:18, 30.72it/s, Materializing param=model.language_model.layers.13.mlp.gate_proj.weight]
# Loading weights:  18%|█▊        | 123/687 [00:03<00:18, 30.72it/s, Materializing param=model.language_model.layers.13.mlp.gate_proj.weight]
# Loading weights:  18%|█▊        | 124/687 [00:03<00:18, 30.72it/s, Materializing param=model.language_model.layers.13.mlp.up_proj.weight]
# Loading weights:  18%|█▊        | 124/687 [00:03<00:18, 30.72it/s, Materializing param=model.language_model.layers.13.mlp.up_proj.weight]
# Loading weights:  18%|█▊        | 125/687 [00:03<00:18, 30.72it/s, Materializing param=model.language_model.layers.13.post_attention_layernorm.weight]
# Loading weights:  18%|█▊        | 125/687 [00:03<00:18, 30.72it/s, Materializing param=model.language_model.layers.13.post_attention_layernorm.weight]
# Loading weights:  18%|█▊        | 126/687 [00:03<00:18, 30.72it/s, Materializing param=model.language_model.layers.13.self_attn.k_proj.weight]
# Loading weights:  18%|█▊        | 126/687 [00:03<00:18, 30.72it/s, Materializing param=model.language_model.layers.13.self_attn.k_proj.weight]
# Loading weights:  18%|█▊        | 127/687 [00:03<00:18, 30.72it/s, Materializing param=model.language_model.layers.13.self_attn.o_proj.weight]
# Loading weights:  18%|█▊        | 127/687 [00:03<00:18, 30.72it/s, Materializing param=model.language_model.layers.13.self_attn.o_proj.weight]
# Loading weights:  19%|█▊        | 128/687 [00:03<00:18, 30.72it/s, Materializing param=model.language_model.layers.13.self_attn.q_proj.weight]
# Loading weights:  19%|█▊        | 128/687 [00:03<00:18, 30.72it/s, Materializing param=model.language_model.layers.13.self_attn.q_proj.weight]
# Loading weights:  19%|█▉        | 129/687 [00:03<00:18, 30.72it/s, Materializing param=model.language_model.layers.13.self_attn.v_proj.weight]
# Loading weights:  19%|█▉        | 129/687 [00:03<00:18, 30.72it/s, Materializing param=model.language_model.layers.13.self_attn.v_proj.weight]
# Loading weights:  19%|█▉        | 130/687 [00:03<00:18, 30.72it/s, Materializing param=model.language_model.layers.14.input_layernorm.weight]
# Loading weights:  19%|█▉        | 130/687 [00:03<00:18, 30.72it/s, Materializing param=model.language_model.layers.14.input_layernorm.weight]
# Loading weights:  19%|█▉        | 131/687 [00:03<00:18, 30.72it/s, Materializing param=model.language_model.layers.14.mlp.down_proj.weight]
# Loading weights:  19%|█▉        | 131/687 [00:03<00:18, 30.72it/s, Materializing param=model.language_model.layers.14.mlp.down_proj.weight]
# Loading weights:  19%|█▉        | 132/687 [00:03<00:18, 30.72it/s, Materializing param=model.language_model.layers.14.mlp.gate_proj.weight]
# Loading weights:  19%|█▉        | 132/687 [00:03<00:18, 30.72it/s, Materializing param=model.language_model.layers.14.mlp.gate_proj.weight]
# Loading weights:  19%|█▉        | 133/687 [00:03<00:18, 30.72it/s, Materializing param=model.language_model.layers.14.mlp.up_proj.weight]
# Loading weights:  19%|█▉        | 133/687 [00:03<00:18, 30.72it/s, Materializing param=model.language_model.layers.14.mlp.up_proj.weight]
# Loading weights:  20%|█▉        | 134/687 [00:03<00:18, 30.72it/s, Materializing param=model.language_model.layers.14.post_attention_layernorm.weight]
# Loading weights:  20%|█▉        | 134/687 [00:03<00:18, 30.72it/s, Materializing param=model.language_model.layers.14.post_attention_layernorm.weight]
# Loading weights:  20%|█▉        | 135/687 [00:03<00:17, 30.72it/s, Materializing param=model.language_model.layers.14.self_attn.k_proj.weight]
# Loading weights:  20%|█▉        | 135/687 [00:03<00:17, 30.72it/s, Materializing param=model.language_model.layers.14.self_attn.k_proj.weight]
# Loading weights:  20%|█▉        | 136/687 [00:03<00:17, 30.72it/s, Materializing param=model.language_model.layers.14.self_attn.o_proj.weight]
# Loading weights:  20%|█▉        | 136/687 [00:03<00:17, 30.72it/s, Materializing param=model.language_model.layers.14.self_attn.o_proj.weight]
# Loading weights:  20%|█▉        | 137/687 [00:03<00:17, 30.72it/s, Materializing param=model.language_model.layers.14.self_attn.q_proj.weight]
# Loading weights:  20%|█▉        | 137/687 [00:03<00:17, 30.72it/s, Materializing param=model.language_model.layers.14.self_attn.q_proj.weight]
# Loading weights:  20%|██        | 138/687 [00:03<00:17, 30.72it/s, Materializing param=model.language_model.layers
687 [00:03<00:03, 167.68it/s, Materializing param=model.language_model.layers.17.mlp.gate_proj.weight]
# Loading weights:  23%|██▎       | 160/687 [00:03<00:03, 167.68it/s, Materializing param=model.language_model.layers.17.mlp.up_proj.weight]
# Loading weights:  23%|██▎       | 160/687 [00:03<00:03, 167.68it/s, Materializing param=model.language_model.layers.17.mlp.up_proj.weight]
# Loading weights:  23%|██▎       | 161/687 [00:03<00:03, 167.68it/s, Materializing param=model.language_model.layers.17.post_attention_layernorm.weight]
# ...
# Loading weights: 100%|█████████▉| 685/687 [00:04<00:00, 974.16it/s, Materializing param=model.vision_tower.vision_model.post_layernorm.weight]
# Loading weights: 100%|█████████▉| 685/687 [00:04<00:00, 974.16it/s, Materializing param=model.vision_tower.vision_model.post_layernorm.weight]
# Loading weights: 100%|█████████▉| 686/687 [00:04<00:00, 974.16it/s, Materializing param=model.vision_tower.vision_model.pre_layrnorm.bias]
# Loading weights: 100%|█████████▉| 686/687 [00:04<00:00, 974.16it/s, Materializing param=model.vision_tower.vision_model.pre_layrnorm.bias]
# Loading weights: 100%|██████████| 687/687 [00:04<00:00, 974.16it/s, Materializing param=model.vision_tower.vision_model.pre_layrnorm.weight]
# Loading weights: 100%|██████████| 687/687 [00:04<00:00, 974.16it/s, Materializing param=model.vision_tower.vision_model.pre_layrnorm.weight]
# Loading weights: 100%|██████████| 687/687 [00:04<00:00, 161.21it/s, Materializing param=model.vision_tower.vision_model.pre_layrnorm.weight]
# [INFO] Building datasets ...
#   Train: 790 | Val: 140
# [INFO] Total steps: 147 | Warmup steps: 7
# [INFO] Trainable parameters:
# trainable params: 15,990,784 || all params: 7,582,738,432 || trainable%: 0.2109
# [INFO] Starting QLoRA fine-tuning ...
#
#   0%|          | 0/150 [00:00<?, ?it/s]
#   1%|          | 1/150 [00:23<58:59, 23.76s/it]
#   1%|▏         | 2/150 [00:42<51:35, 20.91s/it]
#   2%|▏         | 3/150 [01:03<51:14, 20.91s/it]
#   3%|▎         | 4/150 [01:22<49:06, 20.18s/it]
#   3%|▎         | 5/150 [01:44<50:32, 20.92s/it]
#   4%|▍         | 6/150 [02:08<52:48, 22.00s/it]
#   5%|▍         | 7/150 [02:29<51:18, 21.53s/it]
#   5%|▌         | 8/150 [02:50<50:19, 21.26s/it]
#   6%|▌         | 9/150 [03:14<52:06, 22.17s/it]
#   7%|▋         | 10/150 [03:36<51:51, 22.23s/it]
#
#
#   7%|▋         | 10/150 [03:36<51:51, 22.23s/it]
#   7%|▋         | 11/150 [03:55<48:58, 21.14s/it]
#   8%|▊         | 12/150 [04:12<46:02, 20.02s/it]
#   9%|▊         | 13/150 [04:33<45:52, 20.09s/it]
#   9%|▉         | 14/150 [04:55<47:03, 20.76s/it]
#  10%|█         | 15/150 [05:18<47:59, 21.33s/it]
#  11%|█         | 16/150 [05:38<46:52, 20.99s/it]
#  11%|█▏        | 17/150 [06:00<47:16, 21.32s/it]
#  12%|█▏        | 18/150 [06:21<46:32, 21.15s/it]
#  13%|█▎        | 19/150 [06:40<44:46, 20.51s/it]
#  13%|█▎        | 20/150 [06:58<43:08, 19.91s/it]
#
#
#  13%|█▎        | 20/150 [06:58<43:08, 19.91s/it]
#  14%|█▍        | 21/150 [07:20<43:59, 20.46s/it]
#  65%|██████▌   | 98/150 [34:30<19:08, 22.09s/it]
#  66%|██████▌   | 99/150 [34:52<18:48, 22.12s/it]
#  67%|██████▋   | 100/150 [35:00<14:55, 17.91s/it]
#
#
#  67%|██████▋   | 100/150 [35:00<14:55, 17.91s/it]{'loss': '4.563e-05', 'grad_norm': '0.001476', 'learning_rate': '0.0001273', 'epoch': '1.203'}
# {'loss': '4.199e-05', 'grad_norm': '0.0008383', 'learning_rate': '0.0001133', 'epoch': '1.405'}
# {'loss': '3.193e-05', 'grad_norm': '0.0005992', 'learning_rate': '9.93e-05', 'epoch': '1.608'}
# {'loss': '2.898e-05', 'grad_norm': '0.0006891', 'learning_rate': '8.531e-05', 'epoch': '1.81'}
# {'loss': '2.833e-05', 'grad_norm': '0.0006194', 'learning_rate': '7.133e-05', 'epoch': '2'}
#
#
#   0%|          | 0/70 [00:00<?, ?it/s]
#
#   3%|▎         | 2/70 [00:00<00:21,  3.11it/s]
#
#   4%|▍         | 3/70 [00:01<00:39,  1.70it/s]
#
#   6%|▌         | 4/70 [00:02<00:42,  1.55it/s]
#
#   7%|▋         | 5/70 [00:02<00:42,  1.54it/s]
#
#   9%|▊         | 6/70 [00:03<00:41,  1.56it/s]
#
#  10%|█         | 7/70 [00:04<00:39,  1.59it/s]
#
#  11%|█▏        | 8/70 [00:05<00:45,  1.38it/s]
#
#  13%|█▎        | 9/70 [00:05<00:45,  1.34it/s]
#
#  14%|█▍        | 10/70 [00:06<00:43,  1.39it/s]
#
#  16%|█▌        | 11/70 [00:07<00:46,  1.26it/s]
#
#  17%|█▋        | 12/70 [00:08<00:45,  1.27it/s]
#
#  19%|█▊        | 13/70 [00:09<00:42,  1.34it/s]
#
#  20%|██        | 14/70 [00:09<00:39,  1.41it/s]
#
#  21%|██▏       | 15/70 [00:10<00:37,  1.47it/s]
#
#  23%|██▎       | 16/70 [00:10<00:35,  1.51it/s]
#
#  24%|██▍       | 17/70 [00:11<00:34,  1.52it/s]
#
#  26%|██▌       | 18/70 [00:12<00:34,  1.52it/s]
#
#  27%|██▋       | 19/70 [00:12<00:32,  1.55it/s]
#
#  29%|██▊       | 20/70 [00:13<00:31,  1.56it/s]
#
#  30%|███       | 21/70 [00:14<00:35,  1.37it/s]
#
#  31%|███▏      | 22/70 [00:15<00:35,  1.37it/s]
#
#  33%|███▎      | 23/70 [00:15<00:32,  1.43it/s]
#
#  34%|███▍      | 24/70 [00:16<00:31,  1.47it/s]
#
#  36%|███▌      | 25/70 [00:16<00:30,  1.50it/s]
#
#  37%|███▋      | 26/70 [00:17<00:28,  1.54it/s]
#
#  39%|███▊      | 27/70 [00:18<00:27,  1.57it/s]
#
#  40%|████      | 28/70 [00:19<00:30,  1.37it/s]
#
#  41%|████▏     | 29/70 [00:20<00:34,  1.20it/s]
#
#  43%|████▎     | 30/70 [00:20<00:32,  1.23it/s]
#
#  44%|████▍     | 31/70 [00:21<00:29,  1.33it/s]
#
#  46%|████▌     | 32/70 [00:22<00:30,  1.23it/s]
#
#  47%|████▋     | 33/70 [00:23<00:29,  1.26it/s]
#
#  49%|████▊     | 34/70 [00:23<00:26,  1.35it/s]
#
#  50%|█████     | 35/70 [00:24<00:24,  1.42it/s]
#
#  51%|█████▏    | 36/70 [00:25<00:23,  1.45it/s]
#
#  53%|█████▎    | 37/70 [00:26<00:25,  1.30it/s]
#
#  54%|█████▍    | 38/70 [00:27<00:27,  1.16it/s]
#
#  56%|█████▌    | 39/70 [00:27<00:25,  1.21it/s]
#
#  57%|█████▋    | 40/70 [00:28<00:25,  1.16it/s]
#
#  59%|█████▊    | 41/70 [00:29<00:24,  1.20it/s]
#
#  60%|██████    | 42/70 [00:30<00:21,  1.30it/s]
#
#  61%|██████▏   | 43/70 [00:30<00:19,  1.37it/s]
#
#  63%|██████▎   | 44/70 [00:31<00:20,  1.25it/s]
#
#  64%|██████▍   | 45/70 [00:32<00:21,  1.14it/s]
#
#  66%|██████▌   | 46/70 [00:33<00:20,  1.18it/s]
#
#  67%|██████▋   | 47/70 [00:34<00:18,  1.27it/s]
#
#  69%|██████▊   | 48/70 [00:35<00:16,  1.35it/s]
#
#  70%|███████   | 49/70 [00:35<00:14,  1.41it/s]
#
#  71%|███████▏  | 50/70 [00:36<00:13,  1.46it/s]
#
#  73%|███████▎  | 51/70 [00:37<00:14,  1.31it/s]
#
#  74%|███████▍  | 52/70 [00:37<00:13,  1.31it/s]
#
#  76%|███████▌  | 53/70 [00:38<00:12,  1.36it/s]
#
#  77%|███████▋  | 54/70 [00:39<00:11,  1.42it/s]
#
#  79%|███████▊  | 55/70 [00:39<00:10,  1.48it/s]
#
#  80%|████████  | 56/70 [00:40<00:09,  1.53it/s]
#
#  81%|████████▏ | 57/70 [00:41<00:08,  1.56it/s]
#
#  83%|████████▎ | 58/70 [00:42<00:08,  1.37it/s]
#
#  84%|████████▍ | 59/70 [00:42<00:08,  1.37it/s]
#
#  86%|████████▌ | 60/70 [00:43<00:06,  1.44it/s]
#
#  87%|████████▋ | 61/70 [00:44<00:06,  1.30it/s]
#
#  89%|████████▊ | 62/70 [00:45<00:06,  1.16it/s]
#
#  90%|█████████ | 63/70 [00:46<00:06,  1.08it/s]
#
#  91%|█████████▏| 64/70 [00:47<00:05,  1.14it/s]
#
#  93%|█████████▎| 65/70 [00:47<00:03,  1.25it/s]
#
#  94%|█████████▍| 66/70 [00:48<00:03,  1.20it/s]
#
#  96%|█████████▌| 67/70 [00:49<00:02,  1.11it/s]
#
#  97%|█████████▋| 68/70 [00:50<00:01,  1.17it/s]
#
#  99%|█████████▊| 69/70 [00:51<00:00,  1.13it/s]
#
# 100%|██████████| 70/70 [00:52<00:00,  1.05it/s]
#
#
#
#
#  67%|██████▋   | 100/150 [35:54<14:55, 17.91s/it]
#
# 100%|██████████| 70/70 [00:52<00:00,  1.05it/s]
#
#                                                {'eval_loss': '2.586e-05', 'eval_runtime': '53.6', 'eval_samples_per_second': '2.612', 'eval_steps_per_second': '1.306', 'epoch': '2'}
#
#  95%|█████████▍| 142/150 [50:44<02:54, 21.81s/it]
#  95%|█████████▌| 143/150 [51:05<02:30, 21.56s/it]
#  96%|█████████▌| 144/150 [51:27<02:10, 21.69s/it]
#  97%|█████████▋| 145/150 [51:47<01:45, 21.20s/it]
#  97%|█████████▋| 146/150 [52:11<01:28, 22.05s/it]
#  98%|█████████▊| 147/150 [52:30<01:03, 21.11s/it]
#  99%|█████████▊| 148/150 [52:54<00:43, 21.94s/it]
#  99%|█████████▉| 149/150 [53:13<00:20, 20.95s/it]
# 100%|██████████| 150/150 [53:19<00:00, 16.58s/it]
#
#
# 100%|██████████| 150/150 [53:19<00:00, 16.58s/it]
#
#
# 100%|██████████| 150/150 [53:21<00:00, 16.58s/it]
# 100%|██████████| 150/150 [53:21<00:00, 21.34s/it]
# {'loss': '2.548e-05', 'grad_norm': '0.0004152', 'learning_rate': '5.734e-05', 'epoch': '2.203'}
# {'loss': '2.359e-05', 'grad_norm': '0.0006072', 'learning_rate': '4.336e-05', 'epoch': '2.405'}
# {'loss': '2.635e-05', 'grad_norm': '0.0004932', 'learning_rate': '2.937e-05', 'epoch': '2.608'}
# {'loss': '2.464e-05', 'grad_norm': '0.000558', 'learning_rate': '1.538e-05', 'epoch': '2.81'}
# {'loss': '2.46e-05', 'grad_norm': '0.0004863', 'learning_rate': '1.399e-06', 'epoch': '3'}
# {'train_runtime': '3201', 'train_samples_per_second': '0.74', 'train_steps_per_second': '0.047', 'train_loss': '0.01462', 'epoch': '3'}
# [INFO] Saving LoRA adapter → /content/drive/MyDrive/SemiFA/models/llava-semiconductor-qlora
# [DONE] Fine-tuning complete.
#        Adapter saved to: /content/drive/MyDrive/SemiFA/models/llava-semiconductor-qlora
#
# [DONE] Fine-tuning complete ✓
# Adapter saved to: /content/drive/MyDrive/SemiFA/models/llava-semiconductor-qlora

# %% [markdown]
# ## Step 8 — Verify adapter was saved

# %%
import os
from pathlib import Path

adapter_dir = Path(f'{PROJECT_DIR}/models/llava-semiconductor-qlora')
if adapter_dir.exists():
    files = list(adapter_dir.iterdir())
    print(f'Adapter directory: {adapter_dir}')
    print(f'Files ({len(files)}):')
    for f in sorted(files):
        size = f.stat().st_size / 1e6
        print(f'  {f.name:45s}  {size:8.1f} MB')

    adapter_file = adapter_dir / 'adapter_model.safetensors'
    if adapter_file.exists():
        print(f'\nAdapter file: {adapter_file.stat().st_size / 1e6:.1f} MB ✓')
        print('QLoRA fine-tuning COMPLETE — adapter ready for inference.')
    else:
        print('WARNING: adapter_model.safetensors not found — check training logs.')
else:
    print(f'ERROR: {adapter_dir} does not exist.')
# Out:
# Adapter directory: /content/drive/MyDrive/SemiFA/models/llava-semiconductor-qlora
# Files (8):
#   README.md                                           0.0 MB
#   adapter_config.json                                 0.0 MB
#   adapter_model.safetensors                          64.0 MB
#   chat_template.jinja                                 0.0 MB
#   checkpoint-150                                      0.0 MB
#   processor_config.json                               0.0 MB
#   tokenizer.json                                      3.5 MB
#   tokenizer_config.json                               0.0 MB
#
# Adapter file: 64.0 MB ✓
# QLoRA fine-tuning COMPLETE — adapter ready for inference.

# %% [markdown]
# ## Step 9 — Quick inference test with fine-tuned adapter

# %%
import torch
from PIL import Image
from transformers import LlavaNextForConditionalGeneration, LlavaNextProcessor, BitsAndBytesConfig
from peft import PeftModel
import os

BASE_MODEL_ID = 'llava-hf/llava-v1.6-mistral-7b-hf'
ADAPTER_DIR   = f'{PROJECT_DIR}/models/llava-semiconductor-qlora'
HF_TOKEN      = os.environ.get('HF_TOKEN', '')

print('Loading base model + adapter for inference test ...')

bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_quant_type='nf4',
    bnb_4bit_compute_dtype=torch.bfloat16,
    bnb_4bit_use_double_quant=True,
)

# use_fast=False: avoids breaking-change warning; matches training processor behaviour
processor = LlavaNextProcessor.from_pretrained(
    BASE_MODEL_ID, token=HF_TOKEN or None, use_fast=False
)
model = LlavaNextForConditionalGeneration.from_pretrained(
    BASE_MODEL_ID,
    quantization_config=bnb_config,
    device_map='auto',
    token=HF_TOKEN or None,
)

# Load LoRA adapter saved on Drive
model = PeftModel.from_pretrained(model, ADAPTER_DIR)
model.eval()
print('Model + adapter loaded ✓')
# Out:
# Loading base model + adapter for inference test ...
# processor_config.json:   0%|          | 0.00/176 [00:00<?, ?B/s]
# chat_template.json:   0%|          | 0.00/694 [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/772 [00:00<?, ?B/s]
# config.json: 0.00B [00:00, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# tokenizer.model:   0%|          | 0.00/493k [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/41.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/552 [00:00<?, ?B/s]
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 4 files:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/687 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# Model + adapter loaded ✓

# %%
from pathlib import Path
import json, random

# -- System prompt -- must match what was injected during training
SYSTEM_PROMPT = (
    'You are an expert semiconductor failure analysis engineer. '
    'Analyse inspection images and answer questions accurately and concisely.'
)

# Pick a random validation sample
val_records = [json.loads(l) for l in open(f'{PROJECT_DIR}/data/processed/val.jsonl')]
sample = random.choice(val_records)

img_path = Path(PROJECT_DIR) / sample['image']
image = Image.open(img_path).convert('RGB')

# Build prompt (first human turn only) -- strip raw image token from text
question = sample['conversations'][0]['value']
question = question.replace('\n', '').replace('', '').strip()
expected = sample['conversations'][1]['value']

messages = [{'role': 'user', 'content': [
    {'type': 'image'},
    {'type': 'text', 'text': question},
]}]
prompt = processor.apply_chat_template(messages, add_generation_prompt=True)

# Inject system prompt -- identical to training/qlora_finetune.py build_prompt_and_image()
INST_REPLACEMENT = '[INST] <<SYS>>\n' + SYSTEM_PROMPT + '\n<</SYS>>\n\n'
if SYSTEM_PROMPT not in prompt:
    prompt = prompt.replace('[INST]', INST_REPLACEMENT, 1)

inputs = processor(text=prompt, images=image, return_tensors='pt').to(model.device)

print(f'Image    : {img_path.name}')
print(f'Class    : {sample["defect_class"]}')
print(f'Question : {question[:200]}')
print('Generating response ...')

with torch.inference_mode():
    output = model.generate(
        **inputs,
        max_new_tokens=512,
        do_sample=True,
        temperature=0.3,
        top_p=0.9,
        repetition_penalty=1.3,
        no_repeat_ngram_size=4,
        eos_token_id=processor.tokenizer.eos_token_id,
    )

response = processor.decode(
    output[0][inputs['input_ids'].shape[1]:], skip_special_tokens=True
)
print('\n=== FINE-TUNED MODEL RESPONSE ===')
print(response)
print('\n=== EXPECTED (ground truth) ===')
print(expected)
# Out:
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Image    : center_cluster_25.png
# Class    : center_cluster
# Question : You are a semiconductor FA engineer. Analyze this wafer inspection image and generate a structured FA report.
# Generating response ...
#
# === FINE-TUNED MODEL RESPONSE ===
# PRIMARY Failure Mode: Short Circuit
# SUPPORTING EVIDENCE: Reduced Silicides on PN Junction
# ROOT CAUSE: Contamination from Clean Room Environment
# PRIMARY ROOT CAUSE: Particle Impact
# SUPPORTING EVIDENCE: Scratches on Wafer Surface
# ROOT CA USE: Inadequate Filtration in Clean Room
# PRIMary ROOT CAuse: Human Error
# SUPPORTING Evidence: Improper Handling of Wafers
# ROOT CAUse: Lack of Training or Experience
# PRIMARy ROOT CASE: Insufficient Support for New Employee
# SUPPORTING EXAMPLE: No Supervision during Initial Training
# ROOT CA Use: Unsanitary Conditions in Kitchen Area
# PRIMERY ROOT CAause: Poor Maintenance of Equipment
# SUPPORTING ENTRY: Dirty Water Tank in Cooling System
# ROOT CA use: Excessive Humidity in Clean Room Environment
#
# === EXPECTED (ground truth) ===
# DEFECT DESCRIPTION:
# Dense defect cluster within 20 mm of wafer center. The cluster boundary has a circular profile with 54 affected die and a sharp transition to clean die at radius ~31 mm. This sharp boundary distinguishes a discrete process excursion (CMP, spin-coat, or etch) from gradual gradient-based non-uniformity.
#
# ROOT CAUSE HYPOTHESES:
# HYPOTHESIS 1: Spin-coat puddle collapse — resist puddle failed to spread uniformly, leaving thick residue at wafer center that caused subsequent lithography failure
# EVIDENCE: Spin speed unstable (1800 rpm ±96 rpm, spec ±50 rpm) during dispense phase; resist volume 1.6 mL below nominal 2.0 mL
#
# HYPOTHESIS 2: Etch loading effect — center die with higher pattern density experienced reduced etch rate, leaving etch residue
# EVIDENCE: Etch rate center 228 nm/min vs edge 247 nm/min (ratio 1.17, spec <1.15); RATE_NONUNIFORM alarm logged
#
# HYPOTHESIS 3: Wafer backside contamination — particle on wafer backside caused wafer bow, lifting center away from chuck and creating process gap
# EVIDENCE: Wafer bow measurement 64 µm (spec <50 µm); backside particle count 4 detected at pre-process inspection
#
# ROOT CAUSE SUMMARY: Spin coat instability (1800 rpm with ±96 rpm variation) caused non-uniform resist distribution at wafer center. Thick center resist residue survived development, creating the observed center-cluster failure pattern. Spin coater re-qualification required.
#
# SEVERITY: CRITICAL
# ESTIMATED YIELD IMPACT: 4%
# SEVERITY REASONING: CRITICAL — systematic tool process issue will affect all subsequent wafers on this spin coater until speed instability is resolved.
#
# CORRECTIVE ACTIONS:
# 1. Re-qualify spin coater SIM-EQ-02 — check motor encoder, replace if speed variation >±30 rpm at recipe setpoint
# 2. Verify resist dispense nozzle tip condition; replace nozzle if dispense volume deviation >0.1 mL
# 3. Perform in-situ spin speed monitoring for next 10 wafers on SIM-EQ-02; quarantine if speed variation exceeds ±50 rpm
#
# EQUIPMENT FOCUS: Spin coater / track system (equipment: SIM-EQ-02)

# %% [markdown]
# ## Step 10 — DINOv2 Classifier Training & Evaluation
#
# Trains the MLP classification head on top of **frozen DINOv2-base** features.
# Produces real accuracy numbers for the paper.
#
# Expected runtime:
# - **A100 40GB:** ~4–6 min
# - **T4 16GB:** ~8–12 min
#
# Output: per-class Precision / Recall / F1 + overall accuracy on 140 val images.

# %%
import json, time
from pathlib import Path

import torch
import torch.nn as nn
from torch.utils.data import DataLoader
from PIL import Image
from transformers import AutoImageProcessor, AutoModel
from sklearn.metrics import classification_report

DEVICE = 'cuda' if torch.cuda.is_available() else 'cpu'
DINOV2_ID   = 'facebook/dinov2-base'
TRAIN_JSONL = f'{PROJECT_DIR}/data/processed/train.jsonl'
VAL_JSONL   = f'{PROJECT_DIR}/data/processed/val.jsonl'
IMAGE_ROOT  = Path(PROJECT_DIR)
HEAD_SAVE   = f'{PROJECT_DIR}/models/dinov2_head.pt'

DEFECT_CLASSES = [
    'scratch', 'particle_contamination', 'edge_crack',
    'center_cluster', 'local_cluster', 'ring_pattern',
    'random_defects', 'near_full_wafer', 'no_defect',
]
CLASS2IDX = {c: i for i, c in enumerate(DEFECT_CLASSES)}
print(f'Device: {DEVICE}')

# -- load records --
def load_records(p):
    with open(p) as f:
        return [json.loads(l) for l in f if l.strip()]

# -- dataset --
class WaferDS(torch.utils.data.Dataset):
    def __init__(self, records, root):
        self.items = [
            (root / r['image'], CLASS2IDX[r['defect_class']])
            for r in records
            if (root / r['image']).exists() and r.get('defect_class') in CLASS2IDX
        ]
        print(f'  {len(self.items)} images')
    def __len__(self): return len(self.items)
    def __getitem__(self, i):
        p, lbl = self.items[i]
        return Image.open(p).convert('RGB'), lbl

# -- feature extraction --
print('\n[1/4] Loading DINOv2-base ...')
proc_dino = AutoImageProcessor.from_pretrained(DINOV2_ID)
backbone  = AutoModel.from_pretrained(DINOV2_ID).to(DEVICE).eval()
for p in backbone.parameters():
    p.requires_grad = False

def extract(ds, bs=32):
    feats, labels = [], []
    dl = DataLoader(ds, batch_size=bs, shuffle=False,
                    collate_fn=lambda b: list(zip(*b)))
    for imgs, lbls in dl:
        inp = proc_dino(images=list(imgs), return_tensors='pt')
        inp = {k: v.to(DEVICE) for k, v in inp.items()}
        with torch.no_grad():
            out = backbone(**inp)
        feats.append(out.last_hidden_state[:, 0, :].cpu())
        labels.extend(lbls)
    return torch.cat(feats), torch.tensor(labels)

print('[2/4] Extracting features ...')
t0 = time.time()
train_records = load_records(TRAIN_JSONL)
val_records   = load_records(VAL_JSONL)
X_tr, y_tr   = extract(WaferDS(train_records, IMAGE_ROOT))
X_val, y_val = extract(WaferDS(val_records,   IMAGE_ROOT))
print(f'  {time.time()-t0:.1f}s | train={X_tr.shape} val={X_val.shape}')

# -- MLP head --
class MLPHead(nn.Module):
    def __init__(self):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(768, 256), nn.ReLU(), nn.Dropout(0.3), nn.Linear(256, 9)
        )
    def forward(self, x): return self.net(x)

head = MLPHead().to(DEVICE)
opt  = torch.optim.Adam(head.parameters(), lr=1e-3)
crit = nn.CrossEntropyLoss()
Xtr  = X_tr.to(DEVICE);  ytr  = y_tr.to(DEVICE)
Xvd  = X_val.to(DEVICE); yvd  = y_val.to(DEVICE)

print('\n[3/4] Training MLP head (50 epochs) ...')
t0 = time.time()
best_acc, best_state = 0.0, None
BS = 32
for epoch in range(50):
    head.train()
    perm = torch.randperm(len(Xtr))
    for i in range(0, len(Xtr), BS):
        idx = perm[i:i+BS]
        opt.zero_grad()
        crit(head(Xtr[idx]), ytr[idx]).backward()
        opt.step()
    head.eval()
    with torch.no_grad():
        acc = (head(Xvd).argmax(1) == yvd).float().mean().item()
    if acc > best_acc:
        best_acc = acc
        best_state = {k: v.clone() for k, v in head.state_dict().items()}
    if (epoch + 1) % 10 == 0:
        print(f'  epoch {epoch+1:2d}/50  val_acc={acc*100:.1f}%')
print(f'  Done in {time.time()-t0:.1f}s | best={best_acc*100:.1f}%')

# -- evaluation --
print('\n[4/4] Evaluation ...')
head.load_state_dict(best_state)
head.eval()
with torch.no_grad():
    preds = head(Xvd).argmax(1).cpu().numpy()
truth = y_val.numpy()

print('\n' + '='*60)
print('CLASSIFICATION REPORT  (copy into paper Table 2)')
print('='*60)
print(classification_report(truth, preds, target_names=DEFECT_CLASSES, digits=3))
overall = (preds == truth).mean() * 100
print(f'Overall accuracy: {(preds==truth).sum()}/{len(truth)} = {overall:.1f}%')

Path(HEAD_SAVE).parent.mkdir(parents=True, exist_ok=True)
torch.save({'head': best_state, 'classes': DEFECT_CLASSES}, HEAD_SAVE)
print(f'Saved: {HEAD_SAVE}')
# Out:
# Device: cuda
#
# [1/4] Loading DINOv2-base ...
# preprocessor_config.json:   0%|          | 0.00/436 [00:00<?, ?B/s]
# The image processor of type `BitImageProcessor` is now loaded as a fast processor by default, even if the model checkpoint was saved with a slow processor. This is a breaking change and may produce slightly different outputs. To continue using the slow processor, instantiate this class with `use_fast=False`.
# config.json:   0%|          | 0.00/548 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/346M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/223 [00:00<?, ?it/s]
# [2/4] Extracting features ...
#   790 images
#   140 images
#   207.6s | train=torch.Size([790, 768]) val=torch.Size([140, 768])
#
# [3/4] Training MLP head (50 epochs) ...
#   epoch 10/50  val_acc=86.4%
#   epoch 20/50  val_acc=90.0%
#   epoch 30/50  val_acc=89.3%
#   epoch 40/50  val_acc=90.0%
#   epoch 50/50  val_acc=91.4%
#   Done in 2.2s | best=92.1%
#
# [4/4] Evaluation ...
#
# ============================================================
# CLASSIFICATION REPORT  (copy into paper Table 2)
# ============================================================
#                         precision    recall  f1-score   support
#
#                scratch      1.000     0.722     0.839        18
# particle_contamination      1.000     1.000     1.000        10
#             edge_crack      0.933     0.875     0.903        16
#         center_cluster      1.000     1.000     1.000        13
#          local_cluster      0.913     1.000     0.955        21
#           ring_pattern      1.000     0.957     0.978        23
#         random_defects      0.917     0.846     0.880        13
#        near_full_wafer      0.889     0.941     0.914        17
#              no_defect      0.643     1.000     0.783         9
#
#               accuracy                          0.921       140
#              macro avg      0.922     0.927     0.917       140
#           weighted avg      0.935     0.921     0.922       140
#
# Overall accuracy: 129/140 = 92.1%
# Saved: /content/drive/MyDrive/SemiFA/models/dinov2_head.pt

# %% [markdown]
# ## Step 11 — LLaVA Inference Latency Measurement
#
# Times each type of LLaVA call to estimate per-node pipeline latency.
# Run **after Step 9** (requires `model` and `processor` in memory).

# %%
import time, statistics
import torch
from PIL import Image
import numpy as np
from pathlib import Path

try:
    test_img = Image.open(IMAGE_ROOT / val_records[0]['image']).convert('RGB')
except Exception:
    test_img = Image.fromarray(np.random.randint(0, 255, (256,256,3), dtype=np.uint8))

SYS = (
    'You are an expert semiconductor failure analysis engineer. '
    'Analyse inspection images and answer questions accurately and concisely.'
)

def timed_infer(question, n=3, max_tok=256):
    messages = [{'role': 'user', 'content': [
          {'type': 'image'},
          {'type': 'text', 'text': question},
    ]}]
    prompt = processor.apply_chat_template(messages, add_generation_prompt=True)
    INST_REPLACEMENT = '[INST] <<SYS>>\n' + SYS + '\n<</SYS>>\n\n'
    if SYS not in prompt:
          prompt = prompt.replace('[INST]', INST_REPLACEMENT, 1)
    inputs = processor(text=prompt, images=test_img, return_tensors='pt').to(model.device)
    times = []
    for _ in range(n):
        t0 = time.time()
        with torch.inference_mode():
            model.generate(**inputs, max_new_tokens=max_tok,
                           do_sample=False, repetition_penalty=1.1)
        times.append(time.time() - t0)
    return statistics.median(times)

NODES = [
    ('DefectDescriber',
     'Classify the defect in this wafer map image. Describe the spatial pattern, '
     'affected die percentage, and probable physical mechanism.', 200),
    ('RootCauseAnalyzer',
     'Given a scratch defect and a vacuum-chuck pressure alarm at t=-45 min, '
     'generate 3 ranked root cause hypotheses with supporting evidence.', 350),
    ('SeverityClassifier',
     'Assess the severity of this defect (CRITICAL/MAJOR/MINOR/NONE) '
     'and estimate yield impact percentage. Justify your assessment.', 150),
    ('RecipeAdvisor',
     'Provide 3 specific corrective actions and process parameter adjustments '
     'to prevent recurrence of this scratch defect.', 250),
]

print('Timing LLaVA inference (median of 3 runs per node) ...')
print('='*60)
total = 0.0
rows = []
for name, question, max_tok in NODES:
    t = timed_infer(question, n=3, max_tok=max_tok)
    total += t
    rows.append((name, t))
    print(f'  {name:<24}: {t:.1f}s')

rg = 2.5
total += rg
rows.append(('ReportGenerator', rg))
print(f'  ReportGenerator (PDF, no LLM): ~{rg:.1f}s')
print('='*60)
print(f'  TOTAL: {total:.1f}s ({total/60:.1f} min)')
print()
print('-- Table III rows (copy into paper) --')
for name, t in rows:
    pct = t / total * 100
    print(f'  {name:<26} {t:5.1f}s  {pct:4.1f}%')
print(f'  {"Total":<26} {total:5.1f}s  100.0%')
# Out:
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Timing LLaVA inference (median of 3 runs per node) ...
# ============================================================
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#   DefectDescriber         : 22.0s
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#   RootCauseAnalyzer       : 11.9s
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#   SeverityClassifier      : 5.5s
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#   RecipeAdvisor           : 6.5s
#   ReportGenerator (PDF, no LLM): ~2.5s
# ============================================================
#   TOTAL: 48.4s (0.8 min)
#
# -- Table III rows (copy into paper) --
#   DefectDescriber             22.0s  45.5%
#   RootCauseAnalyzer           11.9s  24.6%
#   SeverityClassifier           5.5s  11.4%
#   RecipeAdvisor                6.5s  13.3%
#   ReportGenerator              2.5s   5.2%
#   Total                       48.4s  100.0%

# %% [markdown]
# ## Notes
#
# | Item | Detail |
# |------|--------|
# | Adapter size | ~64 MB (LoRA r=16, 4 modules on Mistral-7B — correct) |
# | Base model size | ~7.5 GB (4-bit NF4) |
# | Total VRAM at inference | ~8.5 GB |
# | Adapter saved to Drive | `MyDrive/SemiFA/models/llava-semiconductor-qlora/` |
# | To load locally | Copy adapter dir to `models/llava-semiconductor-qlora/` |
# | Checkpoint resume | Re-run Step 7 — Trainer auto-resumes from last checkpoint |
# | Merge adapter | `model = model.merge_and_unload()` then `model.save_pretrained(path)` |
# | Inference quality | `repetition_penalty=1.3`, `no_repeat_ngram_size=4`, `do_sample=True, temperature=0.3` |
# | System prompt | Always inject same `<<SYS>>` block at inference as used in training |
# | Improve further | Re-run with `--lr 1e-4` for more stable updates on 790 samples |
# | Clean up Drive | Delete `checkpoint-150/` subdir in adapter dir — `load_best_model_at_end` already merged it |
